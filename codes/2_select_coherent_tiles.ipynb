# %% [markdown]
# ### Select Coherent Tiles
# This notebook will select the coherent tiles and saves them in a new directory. The coherence of the tiles are given as an input to the code. The code will save tiles with more than 90% coherence in the new directory.

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np

# %% [markdown]
# Load data

# %%
# Open the spread sheet
chem = pd.read_csv(r"../data/images_chem_samples.csv")

# %%
# Show the first 5 rows in the spread sheet
chem.head(5)
# Out:
#                                tile_filename  square_from  square_to  \
# 0  MSDP01_009_22.37_23.22-box-0-row-1_12.jpg    23.014047  23.067718
# 1  MSDP01_009_22.37_23.22-box-0-row-1_13.jpg    23.067718  23.121388
# 2  MSDP01_009_22.37_23.22-box-0-row-1_14.jpg    23.121388  23.175059
# 3    MSDP01_009_23.22_24.2-box-0-row-2_0.jpg    23.220000  23.277779
# 4    MSDP01_009_23.22_24.2-box-0-row-2_1.jpg    23.277779  23.335557
#
#    empty_tray  coherent_rock  incoherent_rock  core_block  undetected_region  \
# 0    0.043305       0.956695         0.000000         0.0           0.000000
# 1    0.037119       0.962881         0.000000         0.0           0.000000
# 2    0.197967       0.802033         0.000000         0.0           0.000000
# 3    0.416956       0.000000         0.583044         0.0           0.000000
# 4    0.020328       0.768558         0.000000         0.0           0.211114
#
#    DRILLHOLE_NO  DEPTH_FROM_M  ...  Unnamed: 160 Unnamed: 161 Unnamed: 162  \
# ...

# %%
import shutil
import os

chem_coher = chem[chem['coherent_rock']>0.9]
source = '../data/processed/tiles'
target = '../data/processed/coherent_tiles'

# Create the output directory
os.makedirs(target, exist_ok=True)

# Save coherent tiles in the output directory
for index, row in chem_coher.iterrows():
    src = os.path.join(source, row['tile_filename'].split('_')[0], row['tile_filename'])
    dst = os.path.join(target, row['tile_filename'])
    shutil.copyfile(src, dst)
